# %%
import os
import sys
import pandas as pd
sys.path.append('../Scripts')

from portfolio_performance import PortfolioOptimizer

# %%
# Usage
tsla_path = '../Images/forecasted_data_TSLA_NEW.csv'
bnd_path = '../Images/forecast_BND.csv'
spy_path = '../Images/forecast_spy.csv'

optimizer = PortfolioOptimizer(tsla_path, bnd_path, spy_path)
optimizer.optimize_portfolio()
optimizer.visualize_portfolio()
optimizer.portfolio_summary()
# Out:
# 2024-11-12 15:14:49,139 - INFO - Initializing PortfolioOptimizer.
# 2024-11-12 15:14:49,140 - INFO - Loading data from ../Images/forecasted_data_TSLA_NEW.csv for TSLA.
# 2024-11-12 15:14:49,150 - INFO - Data for TSLA loaded successfully.
# 2024-11-12 15:14:49,153 - INFO - Loading data from ../Images/forecast_BND.csv for BND.
# 2024-11-12 15:14:49,159 - INFO - Data for BND loaded successfully.
# 2024-11-12 15:14:49,160 - INFO - Loading data from ../Images/forecast_spy.csv for SPY.
# 2024-11-12 15:14:49,167 - INFO - Data for SPY loaded successfully.
# 2024-11-12 15:14:49,177 - INFO - PortfolioOptimizer initialization complete.
# 2024-11-12 15:14:49,178 - INFO - Starting portfolio optimization.
# 2024-11-12 15:14:49,210 - INFO - Portfolio optimization complete.
# 2024-11-12 15:14:49,212 - INFO - Optimized weights: [0.01442365 0.16126793 0.82430842]
# 2024-11-12 15:14:49,213 - INFO - Expected annual return: 0.018683566475187856
# ...
