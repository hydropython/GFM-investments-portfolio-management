# %%
import os
import sys
import pandas as pd
sys.path.append('../Scripts')
from Data_feching import FinancialDataFetcher

# %%
# Initialize the class with required parameters
data_fetcher = FinancialDataFetcher(
    tickers=['TSLA', 'BND', 'SPY'],
    start_date='2015-01-01',
    end_date='2024-11-01',
    save_path='../Data',
    image_save_path='../Images'
)

# Fetch the data
data_fetcher.fetch_data()

# Calculate and display volatility
volatility = data_fetcher.calculate_volatility()

# Visualize the volatility comparison
data_fetcher.plot_volatility_comparison(volatility)
# Out:
# 2024-11-12 15:55:48,755 - INFO - FinancialDataFetcher initialized with tickers: ['TSLA', 'BND', 'SPY'], start_date: 2015-01-01, end_date: 2024-11-01, save_path: ../Data, image_save_path: ../Images
# 2024-11-12 15:55:48,756 - INFO - Fetching data for TSLA from 2015-01-01 to 2024-11-01
# [*********************100%***********************]  1 of 1 completed
# 2024-11-12 15:55:53,697 - INFO - Successfully fetched data for TSLA. First few rows:
# Price                      Adj Close      Close       High        Low  \
# Ticker                          TSLA       TSLA       TSLA       TSLA
# Date
# 2015-01-02 00:00:00+00:00  14.620667  14.620667  14.883333  14.217333
# 2015-01-05 00:00:00+00:00  14.006000  14.006000  14.433333  13.810667
# 2015-01-06 00:00:00+00:00  14.085333  14.085333  14.280000  13.614000
# 2015-01-07 00:00:00+00:00  14.063333  14.063333  14.318667  13.985333
# 2015-01-08 00:00:00+00:00  14.041333  14.041333  14.253333  14.000667
#
# Price                           Open    Volume
# Ticker                          TSLA      TSLA
# Date
# 2015-01-02 00:00:00+00:00  14.858000  71466000
# 2015-01-05 00:00:00+00:00  14.303333  80527500
# 2015-01-06 00:00:00+00:00  14.004000  93928500
# 2015-01-07 00:00:00+00:00  14.223333  44526000
# 2015-01-08 00:00:00+00:00  14.187333  51637500
# 2024-11-12 15:55:53,752 - INFO - Data for TSLA saved to ../Data/TSLA_historical_data.csv.
# 2024-11-12 15:55:53,755 - INFO - Fetching data for BND from 2015-01-01 to 2024-11-01
# [*********************100%***********************]  1 of 1 completed
# 2024-11-12 15:55:54,127 - INFO - Successfully fetched data for BND. First few rows:
# Price                      Adj Close      Close       High        Low  \
# Ticker                           BND        BND        BND        BND
# Date
# 2015-01-02 00:00:00+00:00  63.358719  82.650002  82.690002  82.419998
# 2015-01-05 00:00:00+00:00  63.542732  82.889999  82.919998  82.699997
# 2015-01-06 00:00:00+00:00  63.726685  83.129997  83.379997  83.029999
# 2015-01-07 00:00:00+00:00  63.765022  83.180000  83.279999  83.050003
# 2015-01-08 00:00:00+00:00  63.665401  83.050003  83.110001  82.970001
#
# Price                           Open   Volume
# Ticker                           BND      BND
# Date
# 2015-01-02 00:00:00+00:00  82.430000  2218800
# 2015-01-05 00:00:00+00:00  82.739998  5820100
# 2015-01-06 00:00:00+00:00  83.029999  3887600
# 2015-01-07 00:00:00+00:00  83.139999  2433400
# 2015-01-08 00:00:00+00:00  83.110001  1873400
# 2024-11-12 15:55:54,158 - INFO - Data for BND saved to ../Data/BND_historical_data.csv.
# 2024-11-12 15:55:54,159 - INFO - Fetching data for SPY from 2015-01-01 to 2024-11-01
# [*********************100%***********************]  1 of 1 completed
# 2024-11-12 15:55:54,439 - INFO - Successfully fetched data for SPY. First few rows:
# Price                       Adj Close       Close        High         Low  \
# Ticker                            SPY         SPY         SPY         SPY
# Date
# 2015-01-02 00:00:00+00:00  173.173767  205.429993  206.880005  204.179993
# 2015-01-05 00:00:00+00:00  170.046280  201.720001  204.369995  201.350006
# 2015-01-06 00:00:00+00:00  168.444656  199.820007  202.720001  198.860001
# 2015-01-07 00:00:00+00:00  170.543671  202.309998  202.720001  200.880005
# 2015-01-08 00:00:00+00:00  173.569977  205.899994  206.160004  203.990005
#
# Price                            Open     Volume
# Ticker                            SPY        SPY
# Date
# 2015-01-02 00:00:00+00:00  206.380005  121465900
# 2015-01-05 00:00:00+00:00  204.169998  169632600
# 2015-01-06 00:00:00+00:00  202.089996  209151400
# 2015-01-07 00:00:00+00:00  201.419998  125346700
# 2015-01-08 00:00:00+00:00  204.009995  147217800
# 2024-11-12 15:55:54,464 - INFO - Data for SPY saved to ../Data/SPY_historical_data.csv.
# 2024-11-12 15:55:54,466 - INFO - Calculating rolling volatility with a window of 30 days for each asset.
# 2024-11-12 15:55:54,467 - INFO - Calculating volatility for TSLA.
# 2024-11-12 15:55:54,475 - INFO - Calculated volatility for TSLA. Latest value: 0.7751
# 2024-11-12 15:55:54,475 - INFO - Calculating volatility for BND.
# 2024-11-12 15:55:54,479 - INFO - Calculated volatility for BND. Latest value: 0.0403
# 2024-11-12 15:55:54,480 - INFO - Calculating volatility for SPY.
# 2024-11-12 15:55:54,487 - INFO - Calculated volatility for SPY. Latest value: 0.0995
# 2024-11-12 15:55:54,488 - INFO -
# Annualized Volatility for each asset:
# 2024-11-12 15:55:54,489 - INFO - TSLA: 0.7751
# 2024-11-12 15:55:54,490 - INFO - BND: 0.0403
# 2024-11-12 15:55:54,491 - INFO - SPY: 0.0995
# 2024-11-12 15:55:54,491 - INFO - Plotting volatility comparison for TSLA, BND, SPY.
# 2024-11-12 15:55:54,874 - INFO - Volatility comparison plot saved to ../Images/volatility_comparison.png.
