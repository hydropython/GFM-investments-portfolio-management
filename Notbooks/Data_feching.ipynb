# %%
import os
import sys
import pandas as pd
sys.path.append('../Scripts')
from Data_feching import FinancialDataFetcher

# %%
# Initialize the class with required parameters
data_fetcher = FinancialDataFetcher(
    tickers=['TSLA', 'BND', 'SPY'],
    start_date='2015-01-01',
    end_date='2024-11-01',
    save_path='../Data',
    image_save_path='../Images'
)

# Fetch the data
data_fetcher.fetch_data()

# Calculate and display volatility
volatility = data_fetcher.calculate_volatility()

# Visualize the volatility comparison
data_fetcher.plot_volatility_comparison(volatility)
# Out:
# 2024-11-07 21:25:30,170 - INFO - Fetching data for TSLA from 2015-01-01 to 2024-11-01
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 21:25:31,814 - INFO - Data for TSLA saved to ../Data/TSLA_historical_data.csv.
# 2024-11-07 21:25:31,814 - INFO - Fetching data for BND from 2015-01-01 to 2024-11-01
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 21:25:32,146 - INFO - Data for BND saved to ../Data/BND_historical_data.csv.
# 2024-11-07 21:25:32,146 - INFO - Fetching data for SPY from 2015-01-01 to 2024-11-01
# [*********************100%***********************]  1 of 1 completed
# 2024-11-07 21:25:32,440 - INFO - First few rows of SPY data:
# Price                       Adj Close       Close        High         Low  \
# Ticker                            SPY         SPY         SPY         SPY
# Date
# 2015-01-02 00:00:00+00:00  173.173737  205.429993  206.880005  204.179993
# ...
