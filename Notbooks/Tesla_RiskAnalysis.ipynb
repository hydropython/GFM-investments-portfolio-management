# %%
import os
import sys
import pandas as pd
sys.path.append('../Scripts')
from Tesla_RiskAnalysis import TeslaRiskAnalysis

# %%
import logging
if __name__ == "__main__":
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    
    try:
        tsla_risk_analysis = TeslaRiskAnalysis(file_path="../Data/TSLA_historical_data.csv")
        tsla_risk_analysis.summarize_risk_analysis()
    except Exception as e:
        logging.error(f"An error occurred: {e}")
# Out:
# 2024-11-07 21:59:31,279 - INFO - Loading Tesla stock data from: ../Data/TSLA_historical_data.csv
# 2024-11-07 21:59:31,310 - INFO - Stock data loaded successfully. Data shape: (2475, 6)
# 2024-11-07 21:59:31,310 - INFO - Summarizing risk analysis...
# 2024-11-07 21:59:31,310 - INFO - Calculating VaR at 95.0% confidence level...
# 2024-11-07 21:59:31,310 - INFO - Calculating daily returns...
# 2024-11-07 21:59:31,325 - INFO - Calculated VaR: -0.0513
# 2024-11-07 21:59:31,325 - INFO - Value at Risk (VaR) at 95% confidence level: -5.13%
# 2024-11-07 21:59:31,325 - INFO - Calculating Sharpe Ratio...
# 2024-11-07 21:59:31,325 - INFO - Calculating daily returns...
# 2024-11-07 21:59:31,325 - INFO - Calculated Sharpe Ratio: 0.0488
# 2024-11-07 21:59:31,325 - INFO - Sharpe Ratio: 0.05
# 2024-11-07 21:59:31,325 - INFO - Plotting distribution of returns...
# 2024-11-07 21:59:31,325 - INFO - Calculating daily returns...
# Columns in the CSV file: Index(['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# 2024-11-07 21:59:31,804 - INFO - Calculating daily returns...
# 2024-11-07 21:59:31,809 - INFO -
# Summary of Daily Returns:
# 2024-11-07 21:59:31,815 - INFO - count    2474.000000
# mean        0.001786
# std         0.035801
# min        -0.210628
# 25%        -0.016168
# 50%         0.001258
# 75%         0.018951
# max         0.219190
# Name: Daily Return, dtype: float64
